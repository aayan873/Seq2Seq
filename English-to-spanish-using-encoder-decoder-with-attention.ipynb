# %%
import torch
import torch.nn as nn
import pandas as pd

# %%
df = pd.read_csv("Hindi_English_Truncated_Corpus.csv")
df = df.drop(columns=["source"])
df.head()
# Out:
#                                     english_sentence  \
# 0  politicians do not have permission to do what ...
# 1         I'd like to tell you about one such child,
# 2  This percentage is even greater than the perce...
# 3  what we really mean is that they're bad at not...
# 4  .The ending portion of these Vedas is called U...
#
#                                       hindi_sentence
# 0  राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 1  मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# 2   यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।
# 3     हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते
# 4        इन्हीं वेदों का अंतिम भाग उपनिषद कहलाता है।

# %%
import re
from collections import Counter

# %%
dataset = list(zip(df["english_sentence"], df["hindi_sentence"]))
dataset[0]
# Out:
# ('politicians do not have permission to do what needs to be done.',
#  'राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह करने कि अनुमति नहीं है .')

# %%
dataset = [(eng, hindi) for eng, hindi in dataset if isinstance(eng, str) and isinstance(hindi, str)]

# %%
def tokenize(text):
    if not isinstance(text, str):
        return []
    text = text.lower()
    text = re.sub(r"[^a-záéíóúüñ¿¡\u0900-\u097F]+", " ", text)
    return text.strip().split()


def build_vocab(sentences, min_freq=2, specials=["<PAD>", "<SOS>", "<EOS>", "<UNK>"]):
    counter = Counter()
    for sent in sentences:
        counter.update(tokenize(sent))
    
    vocab = {tok: idx for idx, tok in enumerate(specials)}
    for word, freq in counter.items():
        if freq >= min_freq and word not in vocab:
            vocab[word] = len(vocab)
    return vocab

# %%
src_sentences = [eng for eng, _ in dataset]
tgt_sentences = [hindi for _, hindi in dataset]

src_vocab = build_vocab(src_sentences)
tgt_vocab = build_vocab(tgt_sentences)

# %%
from torch.utils.data import Dataset

# %%
class TranslationDataset(Dataset):
    def __init__(self, dataset, src_vocab, tgt_vocab, src_max_len = 25, tgt_max_len = 25):
        self.dataset = dataset
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.src_max_len = src_max_len
        self.tgt_max_len = tgt_max_len

    def tokenize(self, text, is_target=False):
        if not isinstance(text, str):
            return []
        text = text.lower()
        if is_target:
            text = re.sub(r"[^a-záéíóúüñ¿¡\u0900-\u097F]+", " ", text)
        else:
            text = re.sub(r"[^a-záéíóúüñ¿¡]+", " ", text)
        return text.strip().split()

    def numericalize(self, text, vocab, max_len, add_sos_eos=False, is_target=False):
        tokens = self.tokenize(text, is_target=is_target)
        ids = [vocab.get(token, vocab["<UNK>"]) for token in tokens]

        if add_sos_eos:
            ids = [vocab["<SOS>"]] + ids + [vocab["<EOS>"]]

        ids = ids + [vocab["<PAD>"]] * (max_len - len(ids))
        return ids[:max_len]

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        src_text, tgt_text = self.dataset[idx]
        src_ids = self.numericalize(src_text, self.src_vocab, self.src_max_len)
        tgt_ids = self.numericalize(tgt_text, self.tgt_vocab, self.tgt_max_len, add_sos_eos=True, is_target=True)
        return torch.tensor(src_ids), torch.tensor(tgt_ids)

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, num_layers=1):
        super().__init__()
        self.embeddings = nn.Embedding(input_dim, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
    
    def forward(self, X):
        embedded_X = self.embeddings(X) 
        outputs, (hidden, cell) = self.lstm(embedded_X)
        return outputs, (hidden, cell)

# %%
class Attention(nn.Module):
    def __init__(self, hidden_dim):
        super().__init__()
        self.attn = nn.Linear(hidden_dim*2, hidden_dim)
        self.v = nn.Linear(hidden_dim, 1, bias = False)
    
    def forward(self, hidden, encoder_outputs):
        src_len = encoder_outputs.size(1)

        hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)

        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim = 2)))
        attention = self.v(energy).squeeze(2)

        return torch.softmax(attention, dim = 1)

# %%
class DecoderWithAttention(nn.Module):
    def __init__(self, output_dim, embedding_dim, hidden_dim, num_layers=1):
        super().__init__()
        self.embedding = nn.Embedding(output_dim, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim + hidden_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim*2, output_dim)
        self.attention = Attention(hidden_dim)
    
    def forward(self, x, hidden, cell, encoder_outputs):
        x = x.unsqueeze(1)
        embedded = self.embedding(x) 

        attn_weights = self.attention(hidden[-1], encoder_outputs)
        attn_weights = attn_weights.unsqueeze(1)

        weighted_sum = torch.bmm(attn_weights, encoder_outputs)

        lstm_input = torch.cat((embedded, weighted_sum), dim=2)
        output, (hidden, cell) = self.lstm(lstm_input, (hidden, cell))

        output = torch.cat((output.squeeze(1), weighted_sum.squeeze(1)), dim=1)
        prediction = self.fc(output)
        
        return prediction, hidden, cell

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
    
    def forward(self, src, tgt):
        batch_size = src.size(0)
        tgt_len = tgt.size(1)
        vocab_size = self.decoder.fc.out_features
        
        outputs = torch.zeros(batch_size, tgt_len, vocab_size).to(src.device)
        
        enc_outputs, (hidden, cell) = self.encoder(src)
        input_tok = tgt[:, 0]
        
        for t in range(1, tgt_len):
            output, hidden, cell = self.decoder(input_tok, hidden, cell, enc_outputs)
            outputs[:, t, :] = output
            input_tok = tgt[:, t]
        return outputs

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

embed_dim = 256
hidden_dim = 512
num_layers = 1
batch_size = 64
num_epochs = 30
learning_rate = 0.001
teacher_forcing_ratio = 0.5

# %%
max_len = 20
tdataset = TranslationDataset(dataset, src_vocab, tgt_vocab, src_max_len = max_len, tgt_max_len = max_len)
dataloader = DataLoader(tdataset, batch_size = batch_size, shuffle=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
encoder = Encoder(len(src_vocab), embed_dim, hidden_dim, num_layers)
decoder = DecoderWithAttention(len(tgt_vocab), embed_dim, hidden_dim, num_layers)
model = Seq2Seq(encoder, decoder).to(device)

criterion = nn.CrossEntropyLoss(ignore_index=tgt_vocab["<PAD>"])
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
from tqdm import tqdm

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    
    for src_batch, tgt_batch in tqdm(dataloader, desc=f"Epoch {epoch+1}/{num_epochs}"):
        src_batch = src_batch.to(device)
        tgt_batch = tgt_batch.to(device)
        
        optimizer.zero_grad()
        output = model(src_batch, tgt_batch)
        
        output_dim = output.shape[-1]
        output = output[:, 1:, :].contiguous().view(-1, output_dim)
        tgt = tgt_batch[:,1:].reshape(-1)
        
        loss = criterion(output, tgt)
        loss.backward() 
        optimizer.step()
        
        epoch_loss += loss.item()
    
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss/len(dataloader):.4f}")
# Out:
# Epoch 1/30: 100%|██████████| 1994/1994 [14:14<00:00,  2.33it/s]
# Epoch 1/30, Loss: 5.4137
# Epoch 2/30: 100%|██████████| 1994/1994 [14:31<00:00,  2.29it/s]
# Epoch 2/30, Loss: 3.4787
# Epoch 3/30: 100%|██████████| 1994/1994 [14:27<00:00,  2.30it/s]
# Epoch 3/30, Loss: 2.5139
# Epoch 4/30: 100%|██████████| 1994/1994 [15:10<00:00,  2.19it/s]
# Epoch 4/30, Loss: 1.9434
# Epoch 5/30: 100%|██████████| 1994/1994 [15:08<00:00,  2.20it/s]
# Epoch 5/30, Loss: 1.5706
# Epoch 6/30: 100%|██████████| 1994/1994 [15:20<00:00,  2.17it/s]
# Epoch 6/30, Loss: 1.2856
# Epoch 7/30: 100%|██████████| 1994/1994 [15:16<00:00,  2.18it/s]
# Epoch 7/30, Loss: 1.0650
# Epoch 8/30: 100%|██████████| 1994/1994 [15:25<00:00,  2.15it/s]
# Epoch 8/30, Loss: 0.8911
# Epoch 9/30: 100%|██████████| 1994/1994 [14:51<00:00,  2.24it/s]
# Epoch 9/30, Loss: 0.7555
# Epoch 10/30: 100%|██████████| 1994/1994 [14:50<00:00,  2.24it/s]
# Epoch 10/30, Loss: 0.6500
# Epoch 11/30: 100%|██████████| 1994/1994 [14:50<00:00,  2.24it/s]
# Epoch 11/30, Loss: 0.5671
# Epoch 12/30: 100%|██████████| 1994/1994 [14:49<00:00,  2.24it/s]
# Epoch 12/30, Loss: 0.5003
# Epoch 13/30: 100%|██████████| 1994/1994 [14:49<00:00,  2.24it/s]
# Epoch 13/30, Loss: 0.4493
# Epoch 14/30: 100%|██████████| 1994/1994 [14:50<00:00,  2.24it/s]
# Epoch 14/30, Loss: 0.4087
# Epoch 15/30: 100%|██████████| 1994/1994 [14:49<00:00,  2.24it/s]
# Epoch 15/30, Loss: 0.3778
# Epoch 16/30: 100%|██████████| 1994/1994 [14:48<00:00,  2.24it/s]
# Epoch 16/30, Loss: 0.3493
# Epoch 17/30: 100%|██████████| 1994/1994 [14:47<00:00,  2.25it/s]
# Epoch 17/30, Loss: 0.3290
# Epoch 18/30: 100%|██████████| 1994/1994 [14:50<00:00,  2.24it/s]
# Epoch 18/30, Loss: 0.3124
# Epoch 19/30: 100%|██████████| 1994/1994 [14:49<00:00,  2.24it/s]
# Epoch 19/30, Loss: 0.2995
# Epoch 20/30: 100%|██████████| 1994/1994 [14:50<00:00,  2.24it/s]
# Epoch 20/30, Loss: 0.2841
# Epoch 21/30: 100%|██████████| 1994/1994 [14:50<00:00,  2.24it/s]
# Epoch 21/30, Loss: 0.2744
# Epoch 22/30: 100%|██████████| 1994/1994 [14:49<00:00,  2.24it/s]
# Epoch 22/30, Loss: 0.2682
# Epoch 23/30: 100%|██████████| 1994/1994 [09:52<00:00,  3.36it/s]
# Epoch 23/30, Loss: 0.2588
# Epoch 24/30: 100%|██████████| 1994/1994 [08:36<00:00,  3.86it/s]
# Epoch 24/30, Loss: 0.2529
# Epoch 25/30: 100%|██████████| 1994/1994 [08:38<00:00,  3.85it/s]
# Epoch 25/30, Loss: 0.2482
# Epoch 26/30: 100%|██████████| 1994/1994 [08:39<00:00,  3.84it/s]
# Epoch 26/30, Loss: 0.2442
# Epoch 27/30: 100%|██████████| 1994/1994 [08:38<00:00,  3.84it/s]
# Epoch 27/30, Loss: 0.2388
# Epoch 28/30: 100%|██████████| 1994/1994 [08:37<00:00,  3.85it/s]
# Epoch 28/30, Loss: 0.2347
# Epoch 29/30: 100%|██████████| 1994/1994 [08:36<00:00,  3.86it/s]
# Epoch 29/30, Loss: 0.2312
# Epoch 30/30: 100%|██████████| 1994/1994 [08:35<00:00,  3.86it/s]
# Epoch 30/30, Loss: 0.2298

# %%
from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction
from tqdm import tqdm
import random
import torch

def calculate_bleu(model, dataset, src_vocab, tgt_vocab, max_len, sample_size=5, subset_size=500, device="cpu"):
    model.eval()
    candidates = []
    references = []

    inv_tgt_vocab = {v: k for k, v in tgt_vocab.items()}
    smooth_fn = SmoothingFunction().method1

    subset = random.sample(dataset, min(subset_size, len(dataset)))

    for eng, hindi in tqdm(subset, desc="Calculating BLEU"):
        src_tokens = eng.lower().split()
        src_ids = [src_vocab.get(t, src_vocab["<UNK>"]) for t in src_tokens]
        src_ids = src_ids[:max_len]
        src_ids = src_ids + [src_vocab["<PAD>"]] * (max_len - len(src_ids))
        src = torch.tensor(src_ids, dtype=torch.long).unsqueeze(0).to(device)

        with torch.no_grad():
            encoder_outputs, (hidden, cell) = model.encoder(src)
            input_tok = torch.tensor([tgt_vocab["<SOS>"]], dtype=torch.long, device=device)

            result = []
            for _ in range(max_len):
                output, hidden, cell = model.decoder(input_tok, hidden, cell, encoder_outputs)

                next_tok = output.argmax(1).item()

                if next_tok in (tgt_vocab["<EOS>"], tgt_vocab["<PAD>"]):
                    break

                result.append(next_tok)
                input_tok = torch.tensor([next_tok], dtype=torch.long, device=device)

        pred_sentence = [inv_tgt_vocab[i] for i in result if i in inv_tgt_vocab]
        candidates.append(pred_sentence)

        ref_tokens = hindi.strip().split()
        references.append([ref_tokens])

    bleu_score = corpus_bleu(references, candidates, smoothing_function=smooth_fn)

    print(f"\nSample predictions ({sample_size}):\n")
    for i in range(min(sample_size, len(subset))):
        eng, hindi = subset[i]
        pred = " ".join(candidates[i])
        print(f"ENG: {eng}")
        print(f"REF: {hindi}")
        print(f"PRED: {pred}")
        print("-" * 40)

    return bleu_score

# %%
bleu = calculate_bleu(model, dataset, src_vocab, tgt_vocab, max_len, sample_size=500, device = device)
print("BLEU score:", bleu)
# Out:
# Calculating BLEU: 100%|██████████| 500/500 [00:07<00:00, 62.81it/s]
# Sample predictions (500):
#
# ENG: is that feeling and reality get out of whack,
# REF: जब अचानक अहसास और सच्चाई बाहर आते हैं
# PRED: की ये अहसास और सच्चाई को महसूस करने लगा है
# ----------------------------------------
# ENG: But the hunger for mother 's affection , never appeased in childhood , was to survive in the son as a recurring longing for feminine affection and care .
# REF: मां के स्नेह की भूख , जो कि बालक रवि के बचपन में कभी मिट नहीं पाई , और जो स्त्रियों के प्रति अनुराग और स्नेह की आकांक्षा के रूप में बार बार प्रकट होती रही .
# PRED: लेकिन माता के गर्भ में भूख की कमी के लिए उनकी आस्था <UNK> और कभी कोई मामूली नहीं <UNK> क्योंकि
# ----------------------------------------
# ENG: This is clear from the cases found in the Akhabararrat -LRB- provincial -RRB- of Ajmer of the 46th year of Aurangzeb 's reign , discovered in the Deccan .
# REF: यह बात दक्षिण से प्राप्त , औरंगजेब के शासन के 46वें वर्ष के अजमेर सूबे के अखबारात से पता चलती है .
# PRED: यह साफ जानकारी <UNK> <UNK> के <UNK> के द्वारा जून की भूमि <UNK> में दी गयी जो <UNK> <UNK> से
# ----------------------------------------
# ENG: kikani is a beautiful city people come here for their holidays it is 29 kms away from the kathmandu city
# REF: काठमांडु शहर से 29 किमी. उत्तर-पश्चिम में छुट्टियां बिताने की खूबसूरत जगह ककानी स्थित है।
# PRED: काठमांडु शहर से किमी उत्तर पश्चिम में छुट्टियां बिताने की खूबसूरत जगह ककानी स्थित है।
# ----------------------------------------
# ENG: To create that atmosphere and develop this harmony and love is the greatest problem for India today .
# REF: उस तरह का वातावरण उत्पन्न करना तथा जीवन में परस्पर प्रेम और सदभावना विकसित करना भारत के लिए आज की सबसे बड़ी समस्या है .
# PRED: अपनी वातावरण को और आनंद आने के लिए भारत के प्रति प्रेम संघर्ष करना होता है क्योंकि वह आज के
# ----------------------------------------
# ENG: This area is classified in third degree, which means, it is prone to earthquakes of the magnitude of 6.5 on Richter scale.
# REF: इस क्षेत्र को तृतीय श्रेणी में वर्गीकृत किया गया है जिसका अर्थ है कि रिक्टर पैमाने पर 6.5 तीव्रता के भूकम्प आ सकते हैं।
# PRED: इसका क्षेत्र स्रोत तीसरा <UNK> <UNK> यह है जो कि किसी में से नाइट्रोजन का मुंह किया जाएगा
# ----------------------------------------
# ENG: I'm a professor, and we're passionate about education.
# REF: मैं एक प्रोफेसर हूँ, और शिक्षा के बारे में भावुक हूँ|
# PRED: <UNK> <UNK> <UNK> और <UNK> संगीत
# ----------------------------------------
# ENG: I was the second volunteer on the scene,
# REF: मैं आग की जगह पर दूसरा स्वयंसेवक था,
# PRED: मैनें <UNK> पर काम किया लगाया
# ----------------------------------------
# ENG: in the way in which religions set up rituals
# REF: धर्म मे रीति रिवाजों को
# PRED: धर्म मे रीति रिवाजों को
# ----------------------------------------
# ENG: It was , therefore , decided in the Fifth Plan to set up super thermal stations of large capacity , located close to coal-fields .
# REF: इसी कारण कोयला खानों के समीप विशाल क्षमता के उच्च शक़्ति तापघर की स्थापना का निश्चय किया गया .
# PRED: यही कारण था कि <UNK> योजना में <UNK> की कुल क्षमता कम खर्चीली इकाइयों के लिए व्यापक मानव <UNK> की
# ----------------------------------------
# ENG: At that time Mahatma Gandhi had launched a campaign against Roalet Act
# REF: उस समय महात्मा गांधी ने रॉलेट अधिनियम के खिलाफ एक अभियान शुरू किया था।
# PRED: उस समय महात्मा गांधी ने रॉलेट अधिनियम के खिलाफ एक अभियान शुरू किया था।
# ----------------------------------------
# ENG: The question is how can we help Africans do this for themselves?
# REF: प्रश्न ये है कि हम अफ़्रीकी लोगों को ही स्वयं ये करने में मदद कैसे करें?
# PRED: प्रश्न यह कि लोग इस सब को कैसे करने में मदद करने की पूरी नहीं कर सकते हैं।
# ----------------------------------------
# ENG: but they were, being motivated by Marcs and his ideology,to the side of Communist.
# REF: पर वे मार्क्स के सिद्धांतो से प्रभावित थे तथा समाजवाद के पक्षधर ।
# PRED: पर इन दोनों की <UNK> और उनके <UNK> को गणना करके कहते हैं
# ----------------------------------------
# ENG: The psychological interest of the novel lies in the gradual and almost imperceptible transformation in the husband 's feelings towards her .
# REF: उपन्यास का मनोवैज्ञानिक रुझान , उसकी तरफ पति की चाहत का धीरे धीरे बढ़ना और फिर उसके लगभग अतीन्द्रिय संक्रमण में है .
# PRED: उपन्यास का मनोवैज्ञानिक रुझान उसकी तरफ पति की चाहत का धीरे धीरे बढ़ना और उसके बाद आने वाली सफल रहा
# ----------------------------------------
# ENG: The sub-bottom profiler , which penetrates deep under the seabed to give a cross-section view , confirmed the Acropolis structure .
# REF: समुद्र के तल में गहरे जाकर क्षैतिज चित्र लेने वाले सब-बॉटम प्रोफाइलर ने नगर दुर्ग वाली रचना की तो पुष्टि कर दी .
# PRED: <UNK> गहरे <UNK> के आधार पर होने के कारण यह <UNK> मूल परिसर में <UNK> होती है जो <UNK> <UNK>
# ----------------------------------------
# ENG: But the report itself has brought no joy to the Kumaramangalam family .
# REF: वैसे भी रिपोर्ट से कुमारमंगलम परिवार की स्थिति में कोई अंतर नहीं पड़ .
# PRED: वैसे भी रिपोर्ट से कुमारमंगलम परिवार की स्थिति में कोई अंतर नहीं पड़
# ----------------------------------------
# ENG: -is known , which attracts a large number of pilgrims.
# REF: के लिए जाना जाता है जो वर्ष भर तीर्थयात्राओं की एक बड़ी संख्या को आकर्षित करता है।
# PRED: ऋग्वेद की नदीस्तुति के अनुसार वे सात नदियाँ थीं बड़ी संख्या में बड़ी संख्या में बड़ी संख्या में बड़ी संख्या
# ----------------------------------------
# ENG: It was a historic day .
# REF: यह महान ऐतिहासिक दिन था .
# PRED: वह दिन ऐतिहासिक दृष्टि से किया गया था
# ----------------------------------------
# ENG: Tendulkar now considers the 13 coins he won then as some of his most prized possessions
# REF: सचिन के अनुसार उस समय उनके द्वारा जीते गये 13 सिक्के आज भी उन्हे सबसे ज्यादा प्रिय हैं।
# PRED: सचिन के अनुसार उस समय वह अपने अपने क्षेत्र में आकर अपने इतिहास के समान ही कुछ नही बना देते
# ----------------------------------------
# ENG: they designed 52 beautiful water bodies around this town.
# REF: उन्होंने इस कस्बे में 52 सुन्दर पानी के होद बनाए।
# PRED: उन्होंने इस तरह के पानी का होद बनाए।
# ----------------------------------------
# ENG: in the really brilliant mind, and we lose a few social circuits here.
# REF: और कुछ सामाजिक एरिया की नसे कम हो सकती है
# PRED: बहुत सारे <UNK> पी वी और हम कुछ प्रमुख कारण थे
# ----------------------------------------
# ENG: Such compilations were known to the Hindus from the earliest times .
# REF: ऐसी जटिलतांए प्रारंभिक समय से हिंदुओं को ज्ञात थीं .
# PRED: ऐसी <UNK> कि हिंदुओं से ज्ञात हुआ <UNK> ऊण्श्छ्ष् <UNK> अवसर से ही निकल पाए
# ----------------------------------------
# ENG: “”Bhoothnath“”, a film in which he played the role of a ghost was released on 9 may 2008
# REF: ९ मई २००८ भूतनाथ (Bhoothnath) फिल्म में इन्होंने भूत (ghost) के रूप में शीर्षक भूमिका की जिसे रिलीज किया गया।
# PRED: उन्होंने एक फिल्म की भूमिका के आधार पर रिलीज किया जिस में रिलीज हुई भारतीय भूमिका को रिलीज हुई थी
# ----------------------------------------
# ENG: Srimad Bhagavath Gita as it is- Prabhupada
# REF: श्रीमद् भगवद् गीता यथारूप-प्रभुपाद
# PRED: श्रीमद् भगवद् गीता यथारूप प्रभुपाद
# ----------------------------------------
# ENG: a mechanism of delivery of eye care
# REF: आँखों के इलाज को मुहैया करने का प्रबंध
# PRED: आँखों के इलाज को मुहैया करने का प्रबंध
# ----------------------------------------
# ENG: Alternatively , you can write to the Director General of Fair Trading who will , similarly , consider whether a term is unfair .
# REF: अन्यथा आप डायरेक्टर जनरल आफ फेयर ट्रेडिंग को लिख सकते हैं जो तय कर सकेगा कि क्या कोई शर्त अन्यायपूर्ण है या नहीं .
# PRED: अन्यथा मैं आपको बता सकते हैं कि आप <UNK> <UNK> <UNK> क्या प्रतिक्रिया दिये क्या कोई शर्त है क्या तुम्हें
# ----------------------------------------
# ENG: What are you waiting for?
# REF: आप किस बात का इंतजार कर रहे हो ?
# PRED: आप किस तरह की <UNK> हैं
# ----------------------------------------
# ENG: I was lucky enough that I visited Mumbai, my house,
# REF: मैं भाग्यशाली था कि मैं मुंबई गया, मेरे घर,
# PRED: वे भाग्यशाली थी कि मैं अपने काम में <UNK> <UNK> तो बेहद <UNK>
# ----------------------------------------
# ENG: According to world health organization the region of 2-4 million people died in every year directly related to air pollution.where as 1-5 million people are died from indoor air pollution.One study of University of Birmingham is show that the death from the pneumonia and automobile have a relation with death from air pollution.
# REF: विश्व स्वास्थ्य संगठन के अनुसार हर साल २-४ लाख लोगों की मौत का कारण सीधे सीधे वायु प्रदूषण है जबकि इनमे से १-५ लाख लोग आतंरिक वायु प्रदूषण से मारे जाते हैं (indoor air pollution).बर्मिंघम विश्वविद्यालय (University of Birmingham) का एक अध्ययन दिखाता है कि निमोनिया (pneumonia) से होने वाली मौतें और मोटर गाड़ी से होने वाले वायु प्रदूषण से होने वाली मौतों में पक्का सम्बन्ध है.
# PRED: विश्व स्वास्थ्य संगठन के अनुसार हर साल २ ४ लाख लोगों की मौत का कारण सीधे सीधे वायु प्रदूषण अरब
# ----------------------------------------
# ENG: Breadth
# REF: विशालता
# PRED: विशालता
# ----------------------------------------
# ENG: In Hindu religion there number of Devatas which are wrongly classified in English as “gods”.
# REF: हिन्दू धर्म में कई देवता हैं जिनको अंग्रेज़ी मे ग़लत रूप से gods कहा जाता है।
# PRED: हिन्दू धर्म में कई देवता हैं जिनको अंग्रेज़ी मे ग़लत रूप से gods कहा जाता है।
# ----------------------------------------
# ENG: In the constitution parliament representation of government has been told whose formation would be in groups except some exceptions.
# REF: संविधान में सरकार के संसदीय स्वरूप की व्यवस्था की गई है जिसकी संरचना कुछ अपवादों के अतिरिक्त संघीय है।
# PRED: संविधान में सरकार के संसदीय स्वरूप की व्यवस्था की गई है जिसकी संरचना कुछ अपवादों के अतिरिक्त संघीय है
# ----------------------------------------
# ENG: It turned out that Justin was almost
# REF: यह सामने आया कि जस्टिन
# PRED: बिलकुल ऐसा जो कि जस्टिन के
# ----------------------------------------
# ENG: to give too much power
# REF: कि हम बहुत ज्यादा ताकत दे दें
# PRED: बहुत ज्यादा ताकत थी
# ----------------------------------------
# ENG: The major artist of Kathak Dance is Pandit Birju Maharaj.
# REF: कत्थक नृत्य के प्रमुख कलाकार पन्डित बिरजू महाराज हैं।
# PRED: कत्थक नृत्य के प्रमुख कलाकार पन्डित बिरजू महाराज हैं।
# ----------------------------------------
# ENG: across the Middle East, across the path.
# REF: पूरे मध्य-पूर्व में , इस रास्ते के आसपास।
# PRED: पूरे मध्य में भर के मध्य हिस्से पार कर रहे हैं
# ----------------------------------------
# ENG: Maybe the barrier would be too universal.
# REF: शायद ये रुकावट सारे विश्व में फ़ैल जाये।
# PRED: शायद ये रुकावट इतनी भी निकलने वाली भी इतनी पुरानी भी है
# ----------------------------------------
# ENG: often members of the organisation should meet ;
# REF: संघटन के सारे सदस्यों को कभी कभार मिलना चाहिये .
# PRED: संघटन के सारे सदस्यों को <UNK> करना ही चाहिए
# ----------------------------------------
# ENG: There are many species of locusts in the world ; two species of locusts are of particular interest to India .
# REF: विश्व में टिड्डियों की अनेक जातियां हैं.भारत में टिड्डियों की दो जातियां विशेष रूप से महत्वपूर्ण हैं .
# PRED: विश्व में टिड्डियों की अनेक जातियां हैं जिनका विश्व लगभग तीन जातियां हैं जो राष्ट्रीय जातियां हैं उसमें भी किसी
# ----------------------------------------
# ENG: At least, that's how it seems.
# REF: ऐसा ही लग रहा है
# PRED: <UNK> <UNK> यह कैसे रह गया है
# ----------------------------------------
# ENG: On a low income ?
# REF: क्या आप कम आमदनी पर है ?
# PRED: कम आमदनी पर है
# ----------------------------------------
# ENG: But at the same time this temple of Rajaraja II heralds the idea of placing paired Nandis or similar vahanas or lanchanas appropriate in other templeswhich in later times were placed back to back , or coalescent with single neck and headat the corner , with two independent bodies along the two sides .
# REF: पंरतु इसके साथ ही राजराजा द्वितीय का यह मंदिर अन्य मंदिरों में कोनों पर नंदी की जोड़ियों या ऐसे ही वाहनों या लांछनों की स्थापित करने के विचार का आरंभ करता है-जो परवर्ती कालों में पीठ से पीठ सटाकर या समाचयी रूप में एक ग्रीवा और मस्तक किंतु साथ साथ खंड़े दो शरीरों के साथ बनाए गए .
# PRED: पंरतु इसके साथ ही राजराजा द्वितीय का यह मंदिर अन्य मंदिरों में कोनों पर नंदी की जोड़ियों वाले नंदी अथवा
# ----------------------------------------
# ENG: In the south Buddhism became the religion of Sri Lanka . It later spread in the north and east to Tibet , China and Japan . Soon large areas echoed with the sacred hymn :
# REF: यह पूर्व में बर्मा एवं इण्डोचीन तक ; दक्षिण में श्रीलंका तक तथा उत्तर में तिब्बत , चीन और जापान तक फैला और शीघ्र ही दिग-दिगंत में गुंज उठा :
# PRED: भारतीय मंदिरों में यह नया धर्म है तथा बाद में उत्तरी और पूर्व में <UNK> के उत्तर में आता है
# ----------------------------------------
# ENG: Further to be found in the Ganges shark which is due to the popularity of the Ganga flowing water because of sharks found in the world's scientists are very interested.
# REF: इसके अलावा गंगा में पाई जाने वाले शार्क की वजह से भी गंगा की प्रसिद्धि है जिसमें बहते हुये पानी में पाई जानेवाली शार्क के कारण विश्व के वैज्ञानिकों की काफी रुचि है।
# PRED: इसके अलावा गंगा में पाई गई शार्क के अनुसार गंगा में होने वाले शार्क की वजह से भी स्थापित की
# ----------------------------------------
# ENG: The best system of natural brooding is to confine the hen in a coop and allow the chicks into a small separate run which is moved daily along with the coop on to a fresh site .
# REF: प्राकृतिक पालन की श्रेष्ठतम प्रणाली तो यह है कि मुर्गी को एक डिब्बे अथवा पिंजरे में बन्द कर दिया जाये और चूजों को एक छोटे से पृथक् स्थान पर दौड़ने दिया जाये.उनके दौड़ने के इस स्थान को प्रतिदिन पिंजरे के साथ नयी जगह पर ले जाया जाये .
# PRED: प्राकृतिक पालन की श्रेष्ठतम प्रणाली तो यह है कि मुर्गी को एक डिब्बे दी जाती है और एक क्रिया को
# ----------------------------------------
# ENG: and we're kinder and gentler to ourselves.
# REF: और हम अपने प्रति और अधिक दयालू और सहृदय हो जाते हैं।
# PRED: और <UNK> के प्रति <UNK> का ग न करना
# ----------------------------------------
# ENG: This is an architectural monument of the initial Mughal rulers.
# REF: यह आरम्भिक मुगल बादशाहों के वास्तुकला का स्मारक है।
# PRED: यह आरम्भिक मुगल बादशाहों के वास्तुकला का स्मारक है।
# ----------------------------------------
# ENG: Case in point, Einstein.
# REF: मिसाल के तौर पर, आइंस्टाइन।
# PRED: जो <UNK> में १९८६ में रखते हैं
# ----------------------------------------
# ENG: This interim government cannot take any decisions on policy and economy because public assembly is not present at that time. It runs everday administration of the country.
# REF: यह कामचलाऊ सरकार कोई भी वित्तीय/नीतिगत निर्णय नही ले सकती है क्योंकि उस समय लोक सभा मौजूद नही रहती है वह केवल देश का दैनिक प्रशासन चलाती है।
# PRED: यह कामचलाऊ सरकार कोई भी नीति नही नहीं क्योंकि क्योंकि हरियाणा में राज्यों को कोई जगह नही सरकारी नही नीति
# ----------------------------------------
# ENG: Such courts deal and decide the cases and appeals as provided in the Criminal Proce-dure Code .
# REF: ये न्यायालय दंड प्रक्रिया संहिता की व्यवस्थाओं के अनुसार मामलों और अपीलों की सुनवाई तथा निर्णय करते हैं .
# PRED: दंड प्रक्रिया संहिता और अपीलों की सुनवाई करने वाले मामलों पर निर्णय लेती है
# ----------------------------------------
# ENG: Category B : Bills containing provisions involving expenditure from the Consolidated Fund .
# REF: श्रेणी ख : ऐसे विधेयक जिनमें संचित निधि से व्यय संबंधी उपबंध हों .
# PRED: श्रेणी ख जैसे अधिनियमों का निर्देश एन राय ने संविधान मे इसका वर्णन दिया है
# ----------------------------------------
# ENG: Just to give an idea, the world has to stabilize
# REF: सिर्फ एक विचार देने के लिए, दुनिया को स्थिर होना है
# PRED: सिर्फ एक <UNK> देने के लिए दुनिया को स्थिर है
# ----------------------------------------
# ENG: This beautiful sector shaped mausoleum which is made of red marble is surrounded by a beautiful garden.
# REF: सुंदर वृत्तखंड के आकार में लाल बलुआ-पत्थर से निर्मित यह विशाल मकबरा हरे भरे उद्यान के बीच स्थित है।
# PRED: इस बाग में एक बहुत अधिक विकसित हुई है जो कि एक सुंदर रंग ने काले के काले आकार का
# ----------------------------------------
# ENG: This was an attitude quite distant from the spirit of the Lahore Congress .
# REF: यह एक ऐसा रूख था जो लाहौर कांग्रेस की भावना से बहुत भिन्न था .
# PRED: यह एक ऐसा रूख था जो लाहौर कांग्रेस की भावना से बहुत भिन्न था
# ----------------------------------------
# ENG: Be defined
# REF: 1. परिभाषित हो
# PRED: परिभाषित हो
# ----------------------------------------
# ENG: and he says, “Rags, Rags.
# REF: और बोला “रग्स, रग्स”
# PRED: और वह <UNK> <UNK> करता था
# ----------------------------------------
# ENG: In January 2008 at political rallies, Raj Thackeray, the chief of Maharashtra Navnirman Sena, targeted Amitabh Bachchan, asserting that the actor was “”more inclined“” towards his native state than Maharashtra.
# REF: जनवरी २००८ में राजनीतिक रैलियों पर महाराष्ट्र नवनिर्माण सेना (Maharashtra Navnirman Sena) के प्रमुख राज ठाकरे (Raj Thackeray) ने अमिताभ बच्चन को अपना निशाना बनाते हुए कहा कि ये अभिनेता महाराष्ट्र की तुलना में अपनी मातृभूमि के प्रति अधिक रूचि रखते हैं।
# PRED: जनवरी में तीन प्रमुख राज ठाकरे raj thackeray ने राष्ट्र हित के मामले में राजनीतिक अपमान मानव जाति के राज
# ----------------------------------------
# ENG: He took particular interest in the organisation of the Czechoslovak Legion during the first world war outside the country to fight and win freedom for Czechoslovakia .
# REF: प्रथम विश्वयुद्ध के दौरान , चेकोस्लोवाकियाई स्वाधीनता Zको समर्पित संस्था ? चेकोस्लोवाक लीजन ? के चेकोस्लोवाकिया से बाहर स्थापन एवं संगठन की बारीकियों और विशेषताओं को समझने में सुभाष ने विशेष रुचि ली .
# PRED: प्रथम विश्वयुद्ध के दौरान <UNK> स्वाधीनता zको समर्पित संस्था <UNK> लीजन के चेकोस्लोवाकिया से बाहर स्थापन एवं संगठन की मृत्यु
# ----------------------------------------
# ENG: Drill Position
# REF: ड्रिल पोजीशन
# PRED: ड्रिल पोजीशन
# ----------------------------------------
# ENG: the rabbis say, what is the difference between dough that is made into bread,
# REF: रब्बी बताते हैं कि क्या फर्क है उस लोई में जिससे रोटी(खमीर वाली) बनती है,
# PRED: इस बात का प्रमाण क्या है कि मनुष्य के बीच फर्क नहीं होता और मनुष्य <UNK> में अंतर होता है
# ----------------------------------------
# ENG: There were many successful plant and animal breeders millennia before Mendel discovered his laws of heredity , even as there were many astrologers who could empirically predict the time of eclipses long before Newton founded celestial mechanics .
# REF: खगोल विज्ञान में भी ऐसा ही हुआ है.न्यूटन के खगोलीय यांत्रिकी के नियम प्रकाशित किये जाने से बहुत पहले कई लोगों ने अपने अनुभवमूलक ज्ञान के आधार पर ग्रहणों का समय बता दिया था.उसी तरह मेंडेल के नियमों की खोज से हजारों वर्ष पूर्व से पशु तथा पादप प्रजनक अपना काम सफलतापूर्वक करते रहे हैं .
# PRED: खगोल विज्ञान में भी ऐसा ही हुआ है न्यूटन के खगोलीय यांत्रिकी के नियम प्रकाशित किये जाने तथा अन्य विधियों
# ----------------------------------------
# ENG: Decade in the state growth rate was 28.44 percent, while in India the rate was 23.56 percent
# REF: राज्य में दशक वृद्धि दर २८.४४ प्रतिशत थी जबकि भारत में यह दर २३.५६ प्रतिशत थी।
# PRED: राज्य में दशक वृद्धि दर २८ ४४ प्रतिशत थी जबकि भारत में प्रतिवर्ष की दर थी।
# ----------------------------------------
# ENG: This is not trivial.
# REF: यह मामूली नहीं है |
# PRED: यह <UNK> नहीं है
# ----------------------------------------
# ENG: It could not have been Pyongyang .
# REF: प्योंग्यांग इसके लिए मुफीद नहीं हो सकता था .
# PRED: यह <UNK> कतई नहीं थी
# ----------------------------------------
# ENG: iv In the bazars and lanes if any one contrary to regulations and custom has screened off -LRB- Abru -RRB- a part of the street , or closed the part or thrown dirt and sweepings on the road , you should in such cases urge them to remove the violations of regulations .
# REF: बाजारों और गलियों में अगर किसी ने नियमों के विरुद्ध सड़क के किसी हिस्से पर पर्दा डाल दिया है या उसे बंद कर दिया है या सड़क पर कूड़ा करकट फेंक दिया है तो उससे कहो कि नियमों के उल्लंघन को समाप्त करें .
# PRED: और उसके बाद अगर पृथ्वी और गलियों में कोई सदस्य के रूप में कोई फैसल नहीं जमा <UNK> <UNK> के
# ----------------------------------------
# ENG: At that stage , we will endorse the relevant passports and police registration certificates and return them to you together with any other associated documentation .
# REF: उस समय हम पारपत्र और पुलिस में पंजीकरण के प्रमाणपत्र पर उपयुक्त मुहर लगायेंगे और तब यह आप को इस के साथ और जुड़े हुए प्रमाणपत्रों के साथ वापिस कर देंगे .
# PRED: उस पर हम <UNK> और पारपत्र और पुलिस में पंजीकरण के प्रमाणपत्र पर उपयुक्त मुहर लगायेंगे और तब आप को
# ----------------------------------------
# ENG: Again “ the vastly improved design and execution of the Virupaksha temple -LRB- Pattadkal -RRB- built by one of Vikramaditya H 's queens was most likely due to workmen brought from Kanchipuram and to their direct imitation of the Kailasanarha temple which had come into existence in the Pallava capital some decades earlier . ”
# REF: इसी प्रकार “ विक्रमादित्य द्वितीय की रानी द्वारा बनवाए गए विरूपाक्ष मंदिर ( पट्टदकल ) की अत्यधिक उन्नत डिजाइन और निष्पादन , कांचीपुरम से लाए गए कारीगरों और उनके द्वारा कैलासनाथ मंदिर की , जो कुछ दशक पूर्व पल्लव राजधानी में अस्तित्व में आ चुका था , सीधी अनुकृति के कारण ही संभव हो पाया . ”
# PRED: इस बार पूर्ण विकसित हुई और मंदिर पट्टदकल के प्रवेश ने <UNK> के मंदिर में जो मंदिर डिजाइन <UNK> की
# ----------------------------------------
# ENG: I mean, there is a major climate crisis, obviously.
# REF: मेरा मतलब है, यहाँ एक प्रमुख जलवायु संकट, जाहिर है.
# PRED: मैं वहाँ एक प्रमुख योग्य <UNK> है
# ----------------------------------------
# ENG: In winter , the disease generally subsides totally .
# REF: सर्दियों में यह बीमारी प्राय : बिल्कुल ही समाप्त हो जाती है .
# PRED: सर्दियों में यह बीमारी आमतौर पर रखने के मामले में बिल्कुल ही आवश्यकता रहता है
# ----------------------------------------
# ENG: those days gandhiji run a non-cooperation movement against the british government.
# REF: उन दिनों गाँधीजी ने अंग्रेज़ सरकार के खिलाफ असहयोग आंदोलन चलाया था।
# PRED: उन दिनों गाँधीजी ने अंग्रेज़ सरकार के खिलाफ असहयोग आंदोलन चलाया था।
# ----------------------------------------
# ENG: This can be brought against the personal status of ruling
# REF: 4. ये राज्य के साथ ही निजी संस्थान के विरूद्ध भी लायी जा सकती है
# PRED: ये राज्य के साथ ही निजी संस्थान के विरूद्ध भी लायी जा सकती है
# ----------------------------------------
# ENG: The limit of the ground is called boundary,where run is given.Usually a rope is used to signal the outer boundary.
# REF: मैदान की परिधि को सीमा कहा जाता है और इसे कभी कभी रंग दिया जाता है या कभी कभी एक रस्सी के द्वारा मैदान की बाहरी सीमा को चिह्नित किया जाता है।
# PRED: मैदान की नींव रखने की प्रक्रिया कहा जाता है कि <UNK> पर एक बाह्य यौन <UNK> है जो कि एक
# ----------------------------------------
# ENG: I mean, probability and statistics,
# REF: मेरा मतलब संभावना विज्ञान और सांख्यिकीय
# PRED: मैं <UNK> <UNK> और <UNK> में
# ----------------------------------------
# ENG: But the armed forces fear that the tables could easily turn in a future conflict .
# REF: लेकिन भारतीय सेना को आशंका है कि भविष्य में मामल उलट भी सकता है .
# PRED: लेकिन भारतीय सेना को आशंका है कि भविष्य में मामल उलट भी मामल भविष्य में उ आने का दावा करती
# ----------------------------------------
# ENG: Public meetings of sympathy for me and of protest against the judgment of the High Court , were held in almost every considerable town .
# REF: हर शहर में मेरे समर्थन में और उच्च न्यायालय के फैसले के विरोध में सार्वजनिक सभाएं हुईं .
# PRED: इन सबके विरोध के बावजूद और निर्णय के विरुद्ध किये गये सार्वजनिक सभाएं सार्वजनिक सभाएं हुईं दो में से विरोध
# ----------------------------------------
# ENG: This , as an institution , does not exist any more , and has gone with the disappearance of the princely states .
# REF: ढोल ( अवनद्ध-वाद्य ) एक संस्था की तरह अब यह नहीं पाये जाते हैं और रियासतों के साथ यह भी लुप्त हो गए हैं .
# PRED: <UNK> इंस्टीट्यूशन में एक ढोल अवनद्ध वाद्य की घोषणा अब ऐसी नहीं <UNK> और ऊपर से जितनी दूर के न
# ----------------------------------------
# ENG: Lectures of Swami Vivekanand
# REF: स्वामी विवेकानन्द के भाषण
# PRED: स्वामी विवेकानन्द के भाषण
# ----------------------------------------
# ENG: Village and Qasbas -LRB- Caste Courts and Panchayats -RRB- Apart from the above , there was the very important institution of the Panchayat in villages which decided all kinds of cases religious , civil and criminal filed by villagers .
# REF: गांव और कस्बे ( जाति न्यायालय और पंचायतें ) ऊपर्युक्त के अतिरिक्त , गांवों में एक बड़ी महत्वपूर्ण संस्था पंचायत होती थी जो गांव के लोगों द्वारा प्रस्तुत सभी प्रकार के - धार्मिक , सिविल और दांडिक - मामलों का निर्णय करती थी .
# PRED: गांव और कस्बे जाति न्यायालय गांवों में <UNK> और विशेषकर <UNK> के महत्वपूर्ण और भी महत्वपूर्ण थे और चारों ओर
# ----------------------------------------
# ENG: Subhas Chandra arrived some time later alone and introduced himself as an insurance agent on business .
# REF: कुछ देर बाद अकेले पहुंचे सुभाष ने धंधे पर निकले बीमा एजेंट के रूप में अपना परिचय दिया .
# PRED: इससे भी कुछ समय बाद के लोगों ने भी अकेले ही इससे निकले अपने धंधे पर निकले बीमा एजेंट बनाया
# ----------------------------------------
# ENG: Of course, you got it wrong.
# REF: आप बिलकुल ही गलत सोच रहे हो .
# PRED: आप में से <UNK>
# ----------------------------------------
# ENG: you're going to take are going to work on your cancer?
# REF: आप जो लेने वाले हैं वो कैंसर पर काम करने वाली हैं?
# PRED: <UNK> काम करने में आपका काम जारी रहेगी
# ----------------------------------------
# ENG: They had three years , but could not deliver . ”
# REF: उन्हें तीन साल का समय दिया गया था , फिर भी कुछ नहीं हा . ' '
# PRED: तीन साल <UNK> इन तीन तरीकों से अलग नहीं लगी
# ----------------------------------------
# ENG: I was in Ireland during the Troubles 10 years ago,
# REF: मैं १० साल पहले के दंगों के समय आयरलैंड में था,
# PRED: मैं १० साल <UNK> <UNK> साल में हुआ था
# ----------------------------------------
# ENG: Seamonkey 'Complete Web Application Suite' is a part of Hindi awareness campaign of Ashtaank software.
# REF: सीमंकी संपूर्ण इन्टरनेट अनुप्रयोग सुइट अष्टांक सॉफ़्टवेयर के हिन्दी प्रचार प्रसार अभियान का एक अंग है ।
# PRED: सीमंकी संपूर्ण इन्टरनेट अनुप्रयोग सुइट अष्टांक सॉफ़्टवेयर के हिन्दी प्रचार प्रसार अभियान का एक अंग है ।
# ----------------------------------------
# ENG: As he has allegedly claimed he was a farmer.After the scandal broke out, Bachchan surrendered the twenty acres of farmhouse acquired in a place near Maval Pune .
# REF: जैसा कि उन्होंने दावा किया कि उन्हें कथित तौर पर एक किसान माना जाएयदि वह कहीं भी कृषिभूमि के स्वामी के लिए उत्तीर्ण नहीं कर पाते हैं तब इन्हें 20 एकड़ फार्महाउस की भूमि को खोना पड़ सकता है जो उन्होंने मावल पुणे. के निकट खरीदी थी।
# PRED: जैसा कि उन्होंने दावा किया कि उन्हें कथित रूप से उसकी एक ओर एक भाषण में कश्मीर पर प्रतिबंध लगा
# ----------------------------------------
# ENG: Boys are 30 percent more likely than girls
# REF: लड़कियों की तुलना में लड़कों की school drop आउट करने की सम्भावना
# PRED: लड़कियों की तुलना में लड़कों के school भत से अधिक लड़कियों के खेल आ हैं।
# ----------------------------------------
# ENG: Togadia gave up an appreciable practice as a cancer surgeon to become the face of the VHP 's generational shift from the Ashok Singhal era .
# REF: तोगड़िया कैंसर सर्जन की अच्छी-खासी प्रैइक्टस छोड़ेकरौ विहिप का नया चेहरा बने और इस तरह अशोक सिंघल युग से बदलव का प्रतीक बने .
# PRED: तोगड़िया कैंसर सर्जन के प्रति इस तरह के कैंसर का प्रतीक बन गया है वह इस बात का प्रतीक बन
# ----------------------------------------
# ENG: Press photographers are met with demands for “ money before you shoot ” .
# REF: कभी-कभार यह व्यावहारिकता दुखद रूप धारण कर लेती है.प्रेस फोटोग्राफरों से ' फोटो खींचने से पहले ' पैसा मांगा जाता है .
# PRED: <UNK> <UNK> से पहले इस <UNK> का पैसा धीरे पहले से पैसे मिल सके और उनके <UNK> बयान से भी
# ----------------------------------------
# ENG: It is reported that in a particular part of Russia , lung cancer has increased by 50 per cent in the last five years , stomach cancer rates by 30 per cent , and birth defects by about 55 per cent all caused apparently due to excessive use of pesticides .
# REF: यह पता चला है कि रूस के एक विशिष्ट क्षेत्र में फेफड़ों का कैंसर 50 प्रतिशत बढ़ गया है , पेट के कैंसर की दर 30 प्रतिशत बढ़ गयी है और बच्चों में जन्मजात दोष 55 प्रतिशत बढ़ गये हैं-वस्तुतः इन सबका कारण है पीड़कनाशियों का अत्यधिक उपयोग .
# PRED: एक रिपोर्ट के अनुसार केवल रूस का <UNK> हो गया है यदि अंत में कैंसर हो चुकी है यह <UNK>
# ----------------------------------------
# ENG: Amal represents the man whose soul has received the call of the open road . .. ”
# REF: अमल एक ऐसा पात्र है , जिसकी आत्मा ने मुक्त पथ का आह्वान सुना है . ”
# PRED: अमल एक ऐसा पात्र है जिसकी आत्मा ने <UNK> पथ से <UNK> मुक्त पथ नहीं है जिसकी ओर <UNK> यानि
# ----------------------------------------
# ENG: India , a land of diversity in caste , culture and religion , had various sets of laws and its people were governed by different systems .
# REF: जाति , संस्कृति और धर्म के वैविध्य वाले भारत देश में अनेक प्रकार के कानून लागू थे और उसके निवासी भिन्न भिन्न प्रणालियों द्वारा शासित थे .
# PRED: भारत में प्राचीन संसऋ ऊण्श्छ्ष् ऋति जाति धर्म और <UNK> के धर्म में अनेक प्रकार के कानून लागू थे
# ----------------------------------------
# ENG: His main rival is Mamata Banerjee , a tantrum-happy termagant who derives ghoulish pleasure in walking into the prime minister 's drawing room skull and bones in hand .
# REF: उधर , उनकी मुय प्रतिद्वंद्वी तुनुकमिजाज ममता बनर्जी को प्रधानमंत्री के ड़्राइंग रूम में कंकाल और खोपड़ी लेकर घुसने में ही मानो आनंद आता है .
# PRED: उधर उनकी मुय प्रतिद्वंद्वी तुनुकमिजाज ममता के हर <UNK> में एक छोटे अधिकारी की नजर में आ रहे हैं प्रधानमंत्री
# ----------------------------------------
# ENG: This period is called Reeti Kaal as during this period most of the poets wrote poetry on body beautification, in well formulated format and rules of poetry.
# REF: इस काल को रीतिकाल कहा गया क्योंकि इस काल में अधिकांश कवियों ने श्रृंगार वर्णन अलंकार प्रयोग छंद बध्दता आदि के बंधे रास्ते की ही कविता की।
# PRED: इस काल को रीतिकाल कहा गया क्योंकि इस काल में अधिकांश कवियों ने श्रृंगार वर्णन अलंकार प्रयोग छंद बध्दता कहा
# ----------------------------------------
# ENG: She learns quickly , having scalped seven male Grandmasters in two years , including the formidable Russian Mihail Kobalija at Linares , Spain .
# REF: दो साल में उन्होंने सात पुरुष ग्रैंड़ मास्टरों को धूल चटाई , जिनमें रूसी खिलड़ी मिखाइल कोबलिजा को स्पेन में मात देना भी शामिल है .
# PRED: उन्होंने दो साल की उम्र में दो बार एक साथ में <UNK> को दो <UNK> <UNK> कंप्यूटर से निकलने वाल
# ----------------------------------------
# ENG: The oil is skimmed off from the surface with a suction 68 WE BREATHE AND DRINK POISON device .
# REF: एक चूषण-युक्ति द्वारा सतह के ऊपर से तेल को निकाल लिया जाए .
# PRED: किसी भी प्रकार से <UNK> जाता है और <UNK> <UNK> से किया जाता है जिसे हम इस <UNK> <UNK> से
# ----------------------------------------
# ENG: and come this close to you,
# REF: और इतना करीब आ जाऊँ,
# PRED: और इतना करीब आ जाती है
# ----------------------------------------
# ENG: an experience nobody can say, “I am denied of,”
# REF: एक अनुभव जिससे कोई भी इनकार नहीं कर सकता है
# PRED: यह अनुभव किसी <UNK> का विशेषज्ञ अनुभव कर के अनुवाद कर सकती है
# ----------------------------------------
# ENG: For them religion is , as it always was , the highest value .
# REF: उनके लिये जैसाकि हमेशा था , धर्म का उच्चतम मूल्य था .
# PRED: उनके लिए धर्म प्रचार है धर्म उच्चतम अधिक मात्रा में <UNK> मूल्य का प्रयोग था
# ----------------------------------------
# ENG: From the year 2004 he has been injured several times.
# REF: सन् २००४ से वे कई बार चोटग्रस्त रहे हैं।
# PRED: साल के समय में कई कई अधिकारी को अपनी कहानियां मंच दी गई हैं
# ----------------------------------------
# ENG: In 1988 after her death she was given Padmavibhushan award by the Indian govt.
# REF: 1988 में उन्हें मरणोपरांत भारत सरकार की पद्म विभूषण उपाधि से सम्मानित किया गया।
# PRED: में उन्हें मरणोपरांत भारत सरकार की पद्म विभूषण उपाधि से सम्मानित किया गया।
# ----------------------------------------
# ENG: And most security decisions
# REF: और जयादा सुरक्षा निर्णयों में
# PRED: और जयादा सुरक्षा निर्णयों में
# ----------------------------------------
# ENG: Visited Chungking -LRB- China -RRB- in August-Sept . 1939 .
# REF: अगस्त-सितंबर 1939 में चुगकिंग ( चीन ) गया .
# PRED: चीन में <UNK> <UNK> ने भी <UNK> को चीन से किया
# ----------------------------------------
# ENG: Accordingly , the government of India repealed them in 1882 and , the next twelve years , indeed the next forty years , were a period of ' free trade ' with only nominal duties in operation .
# REF: तदनुसार , भारत सरकार ने सन् 1882 में इनको समाप्त कर दिया और अगले 12 वर्ष , वास्तव में आगामी 40 वर्ष का समय , नाम मात्र के शुल्क के कारण , मुक़्त व्यापार का समय था .
# PRED: तदनुसार भारत सरकार ने अपनी शक्तियों से देख रहे हैं इससे अगले साल अप्रैल में स्थित <UNK> यानी वे मद्रास
# ----------------------------------------
# ENG: And if they do , that will go against the nature of Brahman .
# REF: यदि वे ऐसा करते हैं तो ब्रह्म की प्रकृति के विपरित होगा .
# PRED: और अगर वो ऐसे <UNK> करते हैं तो ब्रह्म या फिर <UNK> प्रकृति ने जिन्हें उस पर विपरित पूछताछ किया
# ----------------------------------------
# ENG: I've spent my life
# REF: मैं अपना जीवन बिताया है
# PRED: मेरी उम्र ने मेरा जीवन
# ----------------------------------------
# ENG: India was not endowed with plentiful timber , which could have been a source of industrial power .
# REF: भारत में इमारती लकड़ी की प्रचुरता नहीं थी जो औद्योगिक शक्ति का साधन बन सकती .
# PRED: भारत में इमारती लकड़ी की प्रचुरता नहीं थी जो औद्योगिक शक्ति के अनुकूल <UNK> से ही लगाया
# ----------------------------------------
# ENG: Nothing is easier than to dodge Maxwell 's paradox by affirming the prima facie impossibility of such beings .
# REF: मैक़्सवेल के विरोधाभास से बचने का एक सरल उपाय है कि ऐसे प्राणियों का अस्तित्व ही प्राथमिक तौर पर नकारा जाये .
# PRED: मैक़्सवेल के विरोधाभास से बचने के कारण कुछ दिन तक हो सकता है इस प्रकार दैनिक कि कम करके ऐसे
# ----------------------------------------
# ENG: “”Hindu“” religion have four main sects: “”Vaishnava“”(Those who believe “”Vishnu“” is the Supreme Power“”, “”Shaivs“”(Those who believe shiva is the Supreme Power), “”Shakta“”(Those who believe deity is the Supreme Power)and Samarth(Those who believe that all forms of Supreme Power are one and one).
# REF: हिन्दू धर्म में चार मुख्य सम्प्रदाय हैं : वैष्णव (जो विष्णु को परमेश्वर मानते हैं) शैव (जो शिव को परमेश्वर मानते हैं) शाक्त (जो देवी को परमशक्ति मानते हैं) और स्मार्त (जो परमेश्वर के विभिन्न रूपों को एक ही समान मानते हैं)।
# PRED: चार प्रमुख मत हैं वैष्णव जो मुख्य विश्वास था बहुत शिव थे शैव परमेश्वर का मानना है कि शैव और
# ----------------------------------------
# ENG: because, you know, it's very important.
# REF: क्योंकि, तुम्हें पता है, यह बहुत महत्वपूर्ण है।
# PRED: <UNK> <UNK> बहुत ही लोकप्रिय भाषा में
# ----------------------------------------
# ENG: is to get them a blueprint
# REF: ब्लूप्रिंट को लाना है
# PRED: ब्लूप्रिंट को लाना है
# ----------------------------------------
# ENG: As someone who could not care less whether a temple to Ram was built in Ayodhya or not , I find it hard to understand why Hindus should consider it important .
# REF: एक ऐसे शस के रूप में , जिसे इस बात से कोई फर्क नहीं पड़ेता कि अयोध्या में राम मंदिर बने या नहीं , मैं समज्ह नहीं पाती कि हिंदुओं को यह इतना महत्वपूर्ण क्यों लगता है .
# PRED: एक ऐसे शस है जो में अयोध्या में राम मंदिर न उतरने में किसी मंदिर में होने वाले मुसलमानों को
# ----------------------------------------
# ENG: of Comptroller and Auditor-General have been equated with the judges of the Supreme Court .
# REF: नियंत्रक-महालेखापरीक्षक के वेतन आदि उच्चतम न्यायालय के न्यायाधीशों के वेतन आदि के बराबर रखे गए हैं .
# PRED: नियंत्रक महालेखापरीक्षक के साथ साथ में सुप्रीम कोर्ट की नियुक्ति की जा सकती है
# ----------------------------------------
# ENG: if you're lucky, but after that, honey, you're going to miss me.”
# REF: अगर तुम्हारा नसीब अच्छा रहा, पर उसके बाद, रानी, तुम मुझे भुला न पाओगी.”
# PRED: यदि <UNK> <UNK> पर <UNK> तो उनके <UNK> जाने की आशंका हो
# ----------------------------------------
# ENG: .Masterbation
# REF: मैथुन
# PRED: जनवृत्त
# ----------------------------------------
# ENG: Only in Tajmahal there is a difference;that the main ingredient pavilion,is situated in the end of the garden.
# REF: केवल ताजमहल के बागों में यह असामान्यता है; कि मुख्य घटक मण्डप बाग के अंत में स्थित है।
# PRED: में केवल ताजमहल के प्रधान निर्माण केन्द्र के अनुसार इसे केवल एक सा साधन है
# ----------------------------------------
# ENG: They are of medium size and have a compact body .
# REF: इनका आकार मध्यम और शरीर सुगठित होता है .
# PRED: इनका आकार मध्यम और शरीर सुगठित होता है
# ----------------------------------------
# ENG: Within boundaries, another form which is played is know as Kilikiti. In this, a bat shaped like a hockey is used. In the original English cricket during 1760, the hockey shaped bat was replaced by the more modern straight bat and the bowlers starting pitching instead of throwing. The teams in Estonia gather up in the winters to play ice cricket. Even though it is cold, the Summer rules are followed.
# REF: समोआ में क्रिकेट का एक रूप जो किलिक्ति (Kilikiti) कहलाता है खेला जाता है इसमें हॉकी स्टिक (hockey stick) के आकर के बल्ले का उपयोग किया जाता है. मूल अंग्रेज़ी क्रिकेट में १७६० में हॉकी स्टिक के आकर के बल्ले को आधुनिक सीधे बल्ले से प्रतिस्थापित कर दिया गया जब गेंदबाजों ने इसे घुमाने के बजाय पिच करना शुरू कर दिया. एस्टोनिया में टीमें आइस क्रिकेट (Ice Cricket)टूर्नामेंट के लिए सर्दियों में इकठ्ठी होती हैं. खेल में कठोर सर्दी में गर्मी वाले सभी नियमों का पालन करना होता है. अन्यथा सभी नियम छह-एक-पक्ष के सामान होते हैं.
# PRED: समोआ में क्रिकेट का एक रूप है जिसके ऊपर दूसरे प्रकार के <UNK> में भी खाल से बजाया जाता है
# ----------------------------------------
# ENG: You can do Self-Organized Learning Environments
# REF: आप Self-Organized Learning Environments कर सकते हैं
# PRED: आप <UNK> कर सकते हैं
# ----------------------------------------
# ENG: We need to confront this fear.
# REF: हमें इस डर का सामना करना होगा |
# PRED: इस लिये इस दौरान <UNK> इसे करने की जरूरत है
# ----------------------------------------
# ENG: The green pupa has golden spots in front and a serrate metallic coloured band behind .
# REF: हरे प्यूपा में सामने स्वर्णिम चित्तियां और पीछे दांतेदार धात्विक रंग की पट्टी होती है .
# PRED: हरे प्यूपा में सामने स्वर्णिम चित्तियां और पीछे दांतेदार धात्विक रंग की पट्टी होते हैं
# ----------------------------------------
# ENG: The distance which may be covered during a day depends on the nature of the road , the pace , and the nourishment available .
# REF: एक दिन में तय की जाने वाली दूरी सड़क , चलने की गति और ऊंट को दी जाने वाली खुराक पर निर्भर करती है .
# PRED: जो दिन एक दिन में तय की जाती है वह जिसे दी गई वह सड़क चलने वाली खुराक दी जाती
# ----------------------------------------
# ENG: The DNA-repair deficient cells are obtained from the skin of patients of a genetic disorder called Xeroderma Pigmentosum -LRB- XP -RRB- .
# REF: डी एन ए प्रतिपूर्ति विहीन कोशिकाएं , जीरोडर्मा पिगमैन्टोसन ( ध्फ् ) नामक आनुवंशिक रोग से ग्रस्त रोगियों की त्वचा से प्राप्त की जा सकती है .
# PRED: इन कोशिकाओं में से आनुवंशिक <UNK> आनुवंशिक पदार्थ प्राप्त होती है शरीर <UNK> <UNK> <UNK> नामक आनुवंशिक तंत्र की त्वचा
# ----------------------------------------
# ENG: There's an old African proverb that goes:
# REF: एक पुरानी अफ़्रीकन कहावत है:
# PRED: एक पुरानी अफ़्रीकन जिसका यह <UNK> पुराना <UNK>
# ----------------------------------------
# ENG: The place is connected with one Ramalinga Paradesi , a somewhat cuuous example of a latter-day saint who has been almost deified by his followers .
# REF: इस स्थान का संबंध एक रामलिंग संन्यासी से था , जो बाद मे चलकर साधु हुए तथा बाद में उनके अनुयायियों ने उन्हें देवत्व की संज्ञा दी .
# PRED: इस स्थान को इन चारों ओर जिनको प्रजनन करने वाले टीवी वर्ग के लोगों से भी अधिक रन बनाए गए
# ----------------------------------------
# ENG: Quran teaches its disciples & Hindus have to make a necessary note of it.
# REF: कुरआन अपने अनुयायियों को क्या सिखाता है तथा हम हिन्दुओं के लिए उसे जानना कितना आवश्यक है
# PRED: कुरआन अपने अनुयायियों को क्या सिखाता है तथा हम हिन्दुओं की कृतियों को <UNK> के लिए अपनी रक्षा करना चाहिए
# ----------------------------------------
# ENG: Indian society , all through the centuries , had hardly any middle class , and the accumulation of wealth was never easy during troubled times , in the midst of passing kingdoms and empires and religious and social taboos .
# REF: शताब्दियों तक भारतीय समाज में मध्यम वर्ग जैसा कुछ नहीं था.बनते बिगड़ते राज़्यों और रियासतों के दौर में तथा धार्मिक और सामाजिक प्रतिबंधों के कारण अशांति के समय में धन संचय करना भी कोई आसान नहीं था .
# PRED: भारतीय समाज के महान लेखक जैसे <UNK> का <UNK> भारतीय मध्यम श्रेणी के <UNK> और व्यापारी थे जो वहां भी
# ----------------------------------------
# ENG: So if you're running Namibia for Coca-Cola,
# REF: तो अगर आप कोका-कला के लिए नामीबिया चला रहे हैं ,
# PRED: तो अगर आपने <UNK> के लिए पूरी तरह से <UNK>
# ----------------------------------------
# ENG: Even litigation over the management of the temple , during which any building activity inside the temple was stayed by the courts for some time , did not succeed in budging the locals from their collective belief .
# REF: यहां तक कि मंदिर के प्रबंधन को लेकर चल रहे विवाद से भी-जब अदालत ने मंदिर के भीतर किसी भी तरह के निर्माण कार्य पर रोक लगा दी थी-स्थानीय लग हतोत्साहित नहीं हे .
# PRED: ऐसे मामलों के दौरान <UNK> मंदिर के प्रबंधन के बाद भी जब कोई मूल इमारतें तब तक जब नहीं <UNK>
# ----------------------------------------
# ENG: Varga 's theory was that Great Britain had resumed its general policy of treating India as an agrarian appendage , as a source of raw materials and as a market for British export industries and that , as a result , there was more of ruralisation than industrialisation .
# REF: वर्गा का कहना था कि ग्रेट ब्रिटेन ने भारत को अपना कृषि उत्पादन क्षेत्र , कच्चा माल प्राप्त करने का स्रोत और ब्रिटिश निर्यात उद्योगों की मंडी मानने की सामान्य नीति दोबारा आरंभ की है .
# PRED: वर्गा का कहना था कि ग्रेट ब्रिटेन ने भारत को अपना कृषि उत्पादन क्षेत्र कच्चा माल प्राप्त करने का आदेश
# ----------------------------------------
# ENG: Most of Indians do prayer in temples and their is a long line of his fans in front of the hospital where his treatment doing.
# REF: बहुत से भारतीयों ने मंदिरों में पूजा अर्चनाएं की और इन्हें बचाने के लिए अपने अंग अर्पण किए और बाद में जहां इनका उपचार किया जा रहा था उस अस्पताल के बाहर इनके चाहने वालों की मीलों लंबी कतारें दिखाई देती थी.
# PRED: बहुत से भारतीयों ने मंदिरों में पूजा अर्चनाएं की और इन्हें बचाने के लिए अपने अंग अर्पण किए और उनके
# ----------------------------------------
# ENG: 3)Samdev-A collection of manthras useful for 'udathruvargh' for poojas and prayers.
# REF: (३) सामवेद- इसमें यज्ञानुष्ठान के उद्गातृवर्ग के उपयोगी मन्त्रों का संकलन है।
# PRED: ४ अथर्ववेद इसमें यज्ञानुष्ठान के ब्रह्मवर्ग के उपयोगी मन्त्रों का संकलन है।
# ----------------------------------------
# ENG: So all this vast amount of information is then fed into the computer,
# REF: ये सारी सूचनाये एक कंप्यूटर(computer) को भेजी जाती है
# PRED: तो सारी जानकारी ये विशाल मात्रा में होती है
# ----------------------------------------
# ENG: These are called predisposing factors , that is , factors existing beforehand that predispose someone to , or increase someone 's chances of developing the disease .
# REF: ऐसी स्थितियों या घटकों को ही हम पूर्वप्रवृति घटक कहते हैं.ये घटक मधुमेह होने के कारण नहीं है , परंतु ये मधुमेह होने की संभावना को बढऋआ देते हैं .
# PRED: ऐसे <UNK> मत्कुण <UNK> घटकों के साथ शिव <UNK> <UNK> कहते हैं कि किसी ऐसे <UNK> में जाकर <UNK> नदी
# ----------------------------------------
# ENG: In addition to the usual ration , stud boar should get an ample supplement of mineral mixture .
# REF: सामान्य राशन के अतिरिक़्त प्रजनक सूअर को पूरक भोजन के रूप में खनिज मिश्रण पर्याप्त मात्रा में दिया जाना चाहिए .
# PRED: इसके अतिरिक़्त अण्डों को प्राय <UNK> दूध देने के लिए पर्याप्त मात्रा में दिया जाना चाहिए
# ----------------------------------------
# ENG: Themes
# REF: विषयवस्तु
# PRED: विषयवस्तु
# ----------------------------------------
# ENG: Subhas immediately felt that here was a man who knew what he was about , who was prepared to sacrifice all that he possessed for the cause and could , therefore , demand of others all that they could offer .
# REF: सुभाष को तुरंत यह महसूस हुआ कि यह शख़्स जानता है कि वह क़्या करने जा रहा है , उस लक्ष्यसिद्धि के लिए वह अपना सर्वस्व होम कर देने को तत्पर है और इसी कारण दूसरों से भी अपना सभी कुछ झोंक देने की मांग कर सकता
# PRED: सुभाष को इस मान्यता प्राप्त हुआ जिसका मन में यह जानता था कि क़्या वह कैसा था जो वह जानता
# ----------------------------------------
# ENG: But no , he does not because Pakistan objects to the fact that he considers himself Indian and India is too namby-pamby about what it wants to come down firmly on his side .
# REF: लेकिन नहीं , उन्हें यह अधिकार नहीं है क्योंकि पाकिस्तान को इस बात पर ऐतराज है कि फारूक खुद को भारतीय मानते हैं और किसी बात पर दृढेतापूर्वक उनका साथ देने के मामले मंएं भारत का रुख काफी अस्पष्ट है .
# PRED: लेकिन नहीं तो यह जरूरी नहीं है क्योंकि पाकिस्तान को इस बात की आवश्यकता नहीं है कि फारूक खुद को
# ----------------------------------------
# ENG: We actually have the technology and systems.
# REF: अब वाकई हमारे पास ज़रूरी प्रौद्योगिकी और व्यवस्थाएं मौजूद हैं.
# PRED: और अब वाकई तकनीक है और
# ----------------------------------------
# ENG: A . They did not say that I should be made prime minister .
# REF: उन्होंने यह नहीं कहा कि मुज्हो प्रधानमंत्री बनाया जाए .
# PRED: उन्होंने यह पाया नहीं कि मुज्हो प्रधानमंत्री की पत्नी मुज्हो प्रधानमंत्री <UNK> चाहिए
# ----------------------------------------
# ENG: The chief planner of Nepal's education office than that of Education, five Regional Education Directorates, Peacemaker dist Education Office, Examination Control Office Assimilation, university Education Council, the curriculum development center, various world educational
# REF: नेपालकी शिक्षा का सबसे मुख्य योजनाकार शिक्षामन्त्रालय है उसके अलावा शिक्षा विभाग पाँच क्षेत्रीय शिक्षा निदेशालय पचहतर जिल्ला शिक्षा कार्यालय परीक्षा नियन्त्रण कार्यालय सानोठिमी उच्चमाध्यामिक शिक्षा परिषद्पाठ्यक्रम विकास केन्द्र विभिन्न विश्वविद्यालयों के परीक्षा नियन्त्रण कार्यालय नेपालकी शिक्षाका विकास विस्तार तथा नियन्त्रणके क्षेत्र में कार्यरत हैं ।
# PRED: <UNK> <UNK> <UNK> के कार्यालय को लेकर <UNK> <UNK> जिनकी कहानी मुहैया <UNK> <UNK> शिक्षा आतंकवाद के लिए मुंबई दर्शन
# ----------------------------------------
# ENG: But there is one in regard to which I must say a few words .
# REF: लेकिन एक कारण ऐसा है ऋसके विषय में मुझे कुछ शबऋ-ऊण्श्छ्ष्-द अवशऋ-ऊण्श्छ्ष्-य बोलने चाहिए .
# PRED: लेकिन एक कारण से ऐसा कुछ भी होता है जिसे मुझे कुछ शबऋ ऊण्श्छ्ष् द अवशऋ ऊण्श्छ्ष् य बोलने चाहिए
# ----------------------------------------
# ENG: and they elect a prime minister.
# REF: और वो एक प्रधानमंत्री चुनते हैं।
# PRED: और उन्होंने वो बहोत <UNK> किया वो
# ----------------------------------------
# ENG: The guest lets himself in and finds a seat .
# REF: वह स्वयं द्वारा खोलकर बिछौने पर जा बैठता है .
# PRED: वह स्वयं द्वारा खोलकर बिछौने पर जा बैठता है
# ----------------------------------------
# ENG: His era is used in Mathura and the country of Kanoj .
# REF: उसके काल का प्रयोग मथुरा और कन्नौज प्रदेश में किया जाता है .
# PRED: उसके काल में इनका प्रयोग मथुरा और कन्नौज प्रदेश के <UNK> किया जाता है
# ----------------------------------------
# ENG: So , ever since the business of closing down factories began much money has exchanged hands .
# REF: फैक्टरी बंदी का यह धंधा शुरू होने के बाद काफी रकम इधर से उधर हो चुकी है .
# PRED: फैक्टरी बंदी का यह धंधा शुरू होने के कारण काफी कम रहा है तो <UNK> ने अपनी हाथ <UNK> से
# ----------------------------------------
# ENG: The 46 chromosomes in each somatic or body cell contain the same information as was in the initial zygote .
# REF: शरीर की हर कोशिका में अथवा कायिक कोशिका में उपस्थित 46 में वही जानकारी होती है जो मूल युग़्मज में थी .
# PRED: शरीर के प्रत्येक कोशिका में हर कोशिका की संरचना की संरचना में मूल युग़्मज जीनों द्वारा उसी युग़्मज में विभाजित
# ----------------------------------------
# ENG: Soon after , the losses suffered by the Lankan Army in the troubled north and with the Tigers making a strong comeback , her ability to govern took a serious beating .
# REF: इसके तुरंत बाद तमिल उग्रवादियों के जोरदार हमलं में उत्तरी प्रांत में श्रीलंकाई सेना को ही हानि से उनकी प्रशासकीय क्षमता को जोरदार आघात लगा .
# PRED: इसके तुरंत बाद तमिल उग्रवादियों के जोरदार हमलं में उत्तरी प्रांत में श्रीलंकाई सेना को ही हानि से उनकी उत्तरी
# ----------------------------------------
# ENG: Thus aging and the terminal point of that process , that is death , are not sudden in a normal healthy individual .
# REF: इस प्रकार , वृद्धावस्था और उस प्रक्रिया का अंतिम लक्ष्य मृत्यु , किसी भी सामान्य स्वस्थ मनुष्य के जीवन में अचानक नहीं आती .
# PRED: इस प्रकार वृद्धावस्था और इन सब बातों के बीच संबंध क्रिया का अंत करता था ऐसा लगता है कि मृत्यु
# ...
# ENG: Descartes said we need an entire new way of thinking.
# REF: डेस्कार्टेस ने कहा था कि हमें एक पूरी तरह से नयी सोच की आवश्यकता है।
# PRED: <UNK> ने कहा था कि हमें एक नए ढंग से एक नए ढंग से भी खोजे जाने चाहिए
# ----------------------------------------
# ENG: and all the rest of them move up into the corner,
# REF: और बाकी सब कोने में खिसक जाते हैं जहाँ आयु लम्बी
# PRED: और उन सारे सभी को <UNK> मे इस्तेमाल करें।
# ----------------------------------------
# ENG: This is 26th, that's 27th.”
# REF: ये 26 वाँ और वो 27 वाँ.'
# PRED: ये <UNK> <UNK> <UNK> है
# ----------------------------------------
# ENG: Dissolution of the Assembly - On the advice of the Council of Ninisters, this is done by the President, by which the life of the Assembly ends, after this General Elections only have to be conducted, after the dissolution the pending issues before the Assembly get completed, but bills brought before the Upper House are not completed and kept pending, and the bills under review with the President are also not completed, or the President may call for a sitting of both the Houses of the Parliament before the dissolution of the Assembly.
# REF: लोकसभा का विघटन- राष्ट्रपति द्वारा मंत्रि परिष्द की सलाह पर किया है इससे लोकसभा का जीवन समाप्त हो जाता है इसके बाद आमचुनाव ही होते है विघटन के बाद सभी लंबित कार्य जो लोकसभा के समक्ष होते है समाप्त हो जाते है किंतु बिल जो राज्यसभा मे लाये गये हो और वही लंबित होते है समाप्त न्ही होते या या बिल जो राष्ट्रपति के सामने विचाराधीन हो वे भी समापत नही होते है या राष्ट्रपति संसद के दोनॉ सदनॉ की लोकसभा विघटन से पूर्व संयुक्त बैठक बुला ले
# PRED: लोकसभा की सलाह पर जिनके पास कुल परिषद के आरोप लगाए जाने से यह केवल धीरे धीरे ही प्राप्त हुई
# ----------------------------------------
# ENG: None of the survivors were prepared to talk .
# REF: पर ऐसा कोई भी व्यैक्त बात करने को तैयार नहीं था .
# PRED: पर ऐसा कुछ भी करने की बात नहीं की गयी
# ----------------------------------------
# ENG: Thank you. (Applause)
# REF: धन्यवाद्. (तालियाँ)
# PRED: ओह <UNK> <UNK> धन्यवाद
# ----------------------------------------
# ENG: An article on terrorism and Israel
# REF: कागज और आतंकवाद और इजराइल पर लेख
# PRED: कागज और आतंकवाद और इजराइल पर लेख
# ----------------------------------------
# ENG: a ' rights and responsibilities ' approach that makes Government help available , but requires a contribution from the individual and the community .
# REF: अधिकारों तथा उत्तरदायित्वों का एक रवैय्या अपनाना , ताकि सरकारी उपलब्ध हो सके , परंतु व्यक्तियों और समुदाय को भी योगदान देने की जरुरत हो |भाष्;
# PRED: <UNK> अधिकारों और <UNK> अधिकारों का उत्तरदायित्व जो कि व्यक्ति को भविष्य में <UNK> उपलब्ध नहीं उ भविष्य <UNK> से
# ----------------------------------------
# ENG: It was being realised that the locational aspect of the industry 's development was badly neglected .
# REF: यह अनुभव किया जा रहा था कि उद्योग कि विकास के स्थानीकरण पहलू को बुरी तरह से नकारा जा रहा था .
# PRED: यह अनुभव महसूस किया जा सकता है कि उद्योग ने विकास के स्थानीकरण को बुरी तरह से उन्नति किया
# ----------------------------------------
# ENG: that most things are very home-biased.
# REF: सबसे बातें कि हैं बहुत घर पक्षपाती।
# PRED: सबसे बातें हैं बहुत ही सब बहुत ज़रूरी है।
# ----------------------------------------
# ENG: Ullasam (Tamil) (1997)
# REF: उलासाम (Ullasam)( तमिल ) ( १९९७ )
# PRED: उलासाम ullasam अभियान
# ----------------------------------------
# ENG: Hindi -Urdu machine translation (online)
# REF: हिन्दी-उर्दू मशीन लिप्यंतरण (आनलइन)
# PRED: हिन्दी गद्यकार
# ----------------------------------------
# ENG: We are told that Tagore 's compatriots consider that a new literary period , and the greatest in the history of their language , begins with his appearance .
# REF: लेकिन मेरे कहने का तात्पर्य यह नहीं है कि उनके आगमन से एक नए साहित्यिक युग की शुरुआत हुई है- जो कि उनकी भाषा के इतिहास में सर्वोत्तम है .
# PRED: हम यह कह चुके हैं कि टैगोर ने एक महान साहित्यिक भावनाओं और महान इतिहास की हम पहली और साहित्यिक
# ----------------------------------------
# ENG: It generally occurs during rainy season and takes a severe and rapid course .
# REF: यह रोग वर्षा ऋतु में होता है और शीघ्र ही उग्र रूप धारण कर असर करता है .
# PRED: यह रोग वर्षा ऋतु में होता है और शीघ्र ही उग्र रूप धारण कर असर करता है
# ----------------------------------------
# ENG: One of its branches , however , is trying to take root in a neighbouring farm which belongs to Vallibhai , a paddy farmer .
# REF: मगर इसकी एक शाखा वल्लभभाई नामक किसान के धान के खेत में जा रही है .
# PRED: एक ही शाखा है <UNK> <UNK> एक ऐसा धरती जो किसी भी क्षेत्र में मौजूद हिस्सा ले जाने जा रहे
# ----------------------------------------
# ENG: This is tensor imaging.
# REF: यह टेन्सर इमेजिंग है
# PRED: ये <UNK> <UNK> है
# ----------------------------------------
# ENG: If you have more than one job , you may be able to get SMP from each employer .
# REF: अगर आप एक से जादा नऋकरीयां कर रही हो तो आप को हर एक एम्प्लोयेर् से श्Mफ् मिल सकता है .
# PRED: अगर आप एक से जादा से जादा कर्मचारी बन सकें तो आप को एक एम्प्लोयेर् से श्mफ् मिल कर दो
# ----------------------------------------
# ENG: a film.
# REF: एक फिल्म.
# PRED: एक <UNK> का <UNK>
# ----------------------------------------
# ENG: Whatever this man who has been rightly called an artist in life did became somehow creative and educative , and these tours , apart from their other aspects , became a mission of considerable educative importance , creating a taste in the public for aspects of Indian culture hitherto ignored or despised .
# REF: यह व्यक्ति जिसे सच्चे अर्थों में जीवन का कलाकार कह कर पुकारा गया , अब एक सृष्टिशील शिक्षक के रूप में देखा गया , इन यात्राओं के अन्य पहलुओं के साथ साथ शिक्षणीय महत्ता बढ़ती गई , लोगों के मन में भारतीय संस्कृति के प्रति अनुराग उत्पन्न कराने में सफल रही जो अब तक उपेक्षित या अवांछित पड़ी थी .
# PRED: यह मनुष्य जीवन के आरंभिक कलाकार और उसके बाद अगर एक कलाकार और सामाजिक शिक्षक बन गया
# ----------------------------------------
# ENG: And the food banks are growing.
# REF: और भोजन के भण्डार भी बढ़ रहे हैं.
# PRED: और भोजन के भण्डार तक हो जाते हैं
# ----------------------------------------
# ENG: According to him the physical world is a phenomenon of the Absolute and as such has merely a relative existence .
# REF: उनके अनुसार भौतिक दुनिया परम तत्व की दृश्यमान स्थिति है और इस तरह उसका संबधित अस्तित्व होता है .
# PRED: उनके अनुसार भौतिक दुनिया परम तत्व की दृश्यमान स्थिति है और इस तरह उसका संबधित अस्तित्व होता है
# ----------------------------------------
# ENG: The relationship between information technology and telecom is that of the soul and body .
# REF: सूचना प्रौद्योगिकी और संचार के बीच आत्मा और शरीर जैसा रिश्ता है .
# PRED: सूचना प्रौद्योगिकी के अनुसार प्रौद्योगिकी और उसके शरीर के बारे में रिश्ता और <UNK> जाता है
# ----------------------------------------
# ENG: Because, you know, most people, when they hear
# REF: क्यॊंकि अधिकतर लोग जब यह सुनते हैं
# PRED: <UNK> <UNK> जब आप कभी सुनने की
# ----------------------------------------
# ENG: the extra life boats that were added
# REF: वो अधिक जीवन रक्षक नौकाएं थीं जो रखी गयीं थीं
# PRED: वो अधिक जीवन रक्षक नौकाएं थीं जो रखी गयीं थीं
# ----------------------------------------
# ENG: Meaning of inscription court
# REF: अभिलेख न्यायालय का अर्थ
# PRED: अभिलेख न्यायालय का अर्थ
# ----------------------------------------
# ENG: It is a remarkable document which Evelyn Underhill has described as “ one more amongst the small number of authentic histories of the soul . ”
# REF: यह एक बड़ा ही महत्वपूर्ण दस्तावेज है जिसे एवेलिन अंडरहिल ने “ आत्मा के उन कतिपय प्रामाणिक इतिहासों में से एक बताया है , जो संख्या में बहुत कम हैं . ”
# PRED: यह एक बड़ा ही महत्वपूर्ण दस्तावेज है जिसे <UNK> के पास यहां इसकी <UNK> का काम करता है जिसमें तीन
# ----------------------------------------
# ENG: continue for hours.
# REF: घंटों तक जारी रखना चाहूंगा |
# PRED: पोचमपल्ली साडी लगाने के लिए जारी रखना होगा
# ----------------------------------------
# ENG: In another south Indian village,
# REF: दक्षिण भारत के एक और गाँव में,
# PRED: दक्षिण में भारतीय खान में एक
# ----------------------------------------
# ENG: The tomb of Humayun.
# REF: हुमायुं का मकबरा
# PRED: हुमायुं का मकबरा
# ----------------------------------------
# ENG: the more dramatically the inertia reduces.
# REF: उतनी अधिक गति से जड़ता कम हो जायेगी
# PRED: उतनी अधिक गति से जड़ता को <UNK> मिलता है
# ----------------------------------------
# ENG: We've got to start having conversations like this,
# REF: हमें इस प्रकार सोचना आरंभ करना होगा,
# PRED: <UNK> में <UNK> जैसी करके <UNK> से शुरू हुए
# ----------------------------------------
# ENG: Now, I was 16. I was very worried about
# REF: मैं 16 साल का था | मैं घबरा गया कि
# PRED: <UNK> मैं अपने आप को लगभग एक किताब कार्यक्रम पड़ा
# ----------------------------------------
# ENG: Rivals , however , insist that the probes are motivated , either to nail political opponents or to sweep contentious issues under the carpet .
# REF: लेकिन विरोधियों का कहना है कि ये जांच राजनीति प्रेरित हैं-विरोधियों को चुप करने के लिए या विवादास्पद मसलं को ंडऋए बस्ते में डऋआलने के लिए है .
# PRED: लेकिन विरोधियों जो इस बात के अनुसार दूर रहते हैं कि <UNK> <UNK> या <UNK> को चुप रहने की राजनीति
# ----------------------------------------
# ENG: Union leaders claim that 24 of their 25 demands have been met .
# REF: श्रमिक संघों के नेताओं का कहना है कि उनकी 25 में से 24 मांगें मान ली गई हैं .
# PRED: केंद्रीय शिक्षा के अनुसार जो <UNK> के नेताओं का कहना है उनके लिए भले ही हो गया है कि संघ
# ----------------------------------------
# ENG: We analysed relevant data and worked with the Office for National Statistics -LRB- ONS -RRB- in order to establish better estimates of the incidence of low pay .
# REF: हम ने संगत आकडों का विश्लेषण किया वेतन की घटनाओं का बेहतर अनुमान लगाने के लिए अऑफिस अऑफ नैशनल स्टैटिस्टक्स ( औण्श् ) के साथ मिलकर किया .
# PRED: हम ने संगत आकडों का विश्लेषण किया है खासकर के लिए विश्वसनीय जानकारी के <UNK> ग्रंथ की घटनाओं के महज
# ----------------------------------------
# ENG: Midway through the Plan , infrastructure constraints , particularly inadequacy of coking coal , affected production adversely .
# REF: योजना के मध्य , सरंचनात्मक अवरोधों , विशेषकर Zकोकिंग कोयले की कमी ने उत्पादन को बुरी तरह से प्रभावित किया .
# PRED: योजना के अनुसार <UNK> <UNK> विशेषकर <UNK> के कोयले में विशेषकर कोयला और उत्पादन सन् के मध्य करोड़ टन संगठित
# ----------------------------------------
# ENG: Therefore , the times in which Saturn and the moon traverse the same space are different , whilst their motions are equal .
# REF: यही कारण है कि जिस समय में शनि और चंद्र एक ही देश की यात्रा करते हैं वह भिन्न होता है जबकि उनकी गति समान होती है .
# PRED: यही कारण है कि जिस समय में शनि और चंद्र एक ही देश की यात्रा करते हुए यहाँ भारत के
# ----------------------------------------
# ENG: Great poet and writer Mahadevi Verma, apart from being excellent in literature and music, was a great painter and creative translation.
# REF: प्रतिभावान कवयित्री और गद्य लेखिका महादेवी वर्मा साहित्य और संगीत में निपुण होने के साथ साथ कुशल चित्रकार और सृजनात्मक अनुवादक भी थीं।
# PRED: प्रतिभावान कवयित्री और गद्य लेखिका महादेवी वर्मा साहित्य और संगीत में निपुण होने के साथ साथ कुशल चित्रकार और संगीत
# ----------------------------------------
# ENG: raipur,chhatisgarh related information, newspaper and directory
# REF: रायपुर छत्तीसगढ़ से सम्बंधित जानकारियां समाचार पत्र एंव डायरेक्टरी (यूनिकोडित)
# PRED: <UNK> <UNK> ए गरीबी कहानी और <UNK>
# ----------------------------------------
# ENG: if they really had technology assessment?
# REF: अगर उनके पास तकनिकी सहायता होती ?
# PRED: अगर उन्होंने सच में इस्तेमाल किया है
# ----------------------------------------
# ENG: in her arms.
# REF: अपनी गोद में.
# PRED: उसकी गोद में
# ----------------------------------------
# ENG: It was the barrister who would be in the best position to fight for India 's self-respect and advancement both at the level of the individual in his demand for justice , and at the level of the people in their claim for their rights .
# REF: भारत के आत्मसम्मान और विकास के लिए जूझने में बैरिस्टर ही सबसे अच्छा सिद्ध होता , चाहें वह व्यक़्तिगत स्तर पर न्याय की मांग हो या जनता के स्तर पर उनके अधिकारों की बात .
# PRED: भारत के आत्मसम्मान और विकास के लिए जूझने में बैरिस्टर सबसे अच्छा काम किया जिसने दोनों किस्म के स्तर को
# ----------------------------------------
# ENG: Sariputra and Moggallana were both important members of the Sangha and were required for various administrative jobs .
# REF: सारिपुत्र और मोग़्गलान दोनों ही संघ के प्रमुख कार्यकर्ता थे संघ के प्रशासनिक कामों के लिए उन दोनों की बहुत आवश्यकता थी .
# PRED: सारिपुत्र और मोग़्गलान दोनों ही संघ के प्रमुख कार्यकर्ता थे संघ के प्रशासनिक कामों के लिए दोनों सेवाओं की उन
# ----------------------------------------
# ENG: In taking anti-colonialism to ridiculous extremes , we failed to appreciate that the foreign policy of the British Raj was primarily centred not on Britain but on India and Indian interests .
# REF: उपनिवेशवाद का हद से ज्यादा विरोध करने के चलते हमने इस बात की अनदेखी कर दी कि ब्रिटिश राज की विदेश नीति मुय तौर पर ब्रिटेन केंद्रित न होकर भारत और भारतीय हितों पर केंद्रित थी .
# PRED: उपनिवेशवाद पर <UNK> के चलते यह बात ऐसी ब्रिटिश सरकार के लिए बुनियादी था इस कदर व्यापक ब्रिटिश सरकार ने
# ----------------------------------------
# ENG: You made me feel like I was somebody,
# REF: आपने मुझे जताया कि मैं भी कुछ था,
# PRED: आप ने मुझे जताया कि मैं भी <UNK> था
# ----------------------------------------
# ENG: It can also harvest something like 25,000 in a good monsoon.
# REF: अच्छे मानसून में यह 25 हज़ार के लगभग संरक्षण भी कर सकता है।
# PRED: कुछ अच्छा हुआ कुछ पर्दे के अन्दर भी मिलते हैं।
# ----------------------------------------
# ENG: The world progresses and advances in knowledge and culture even though there are occasional lapses and retrogression .
# REF: शिक्षा और संस्कृति को लेकर दुनिया तरक़्की करती और आगे बढ़ती है , हालांकि कभी कभी इसमें रूकावट आ जाती है और पीछे हटना पड़ता है .
# PRED: शिक्षा और संस्कृति को लेकर दुनिया तरक़्की करती और वैसे भी इसमें रूकावट आ जाती है
# ----------------------------------------
# ENG: Bullocks are specially suited for trotting and quick transport .
# REF: इस नस्ल के बैल दुलकी चाल पर काम करने तथा शीघ्र परिवहन के लिए विशेष रूप से उपयुक़्त होते हैं .
# PRED: इस नस्ल के बैल दुलकी चाल पर काम करने तथा शीघ्र परिवहन के लिए अधिक उपयुक़्त होते है
# ----------------------------------------
# ENG: He is famous for the little gems of poetry called shatakas which show great depth of conception and artistic skill .
# REF: वे थोड़े काव्य रत्नों के लिये विख़्यात हैं , जिन्हें शतक कहा जाता है , जो सिद्धांतों तथा कला कौशल की बड़ी गहरायी प्रकट करते है .
# PRED: वे थोड़े काव्य रत्नों के लिये विख़्यात हैं जो सिद्धांतों तथा व्रत के सिद्धांतों में मिलाकर याद है विशेष कला
# ----------------------------------------
# ENG: we didn't have enough resources,
# REF: हमारे पास पर्याप्त संसाधन नहीं थे,
# PRED: <UNK> <UNK> ने जो हमारे पास पर्याप्त है
# ----------------------------------------
# ENG: According to Buddha Religion is this:
# REF: बुद्ध के अनुसार धम्म यह है:
# PRED: बुद्ध के अनुसार धम्म यह है धर्म
# ----------------------------------------
# ENG: A pioneering collection of mosquito DNA is helping scientists to track down the spread of malaria .
# REF: मच्छरों के डीएनए का प्रमुख संग्रह वै&आनिकों को मलेरिया फैलने का पता लगाने में सहायता कर रहा है .
# PRED: मच्छरों के डीएनए का प्रमुख संग्रह वै आनिकों को मलेरिया फैलने की कल करने में सहायता मिल सकता है
# ----------------------------------------
# ENG: when our distributions stabilize.
# REF: जब हमारा वितरण स्थिर हो जाता है.
# PRED: जब हमारे काम का वितरण करते हैं
# ----------------------------------------
# ENG: The religious ideal according to the Upanishads is the realisation of the unity of Being .
# REF: उपनिषद् के अनुसार धार्मिक आदर्श , सत्तात्मक एकता की उपलब्धियां है .
# PRED: उपनिषद् के अनुसार धार्मिक आदर्श सत्तात्मक एकता की उपलब्धियां है
# ----------------------------------------
# ENG: They walk and run with great speed on the water surface .
# REF: ये पानी की सतह पर बहुत तेज गति से चलते और दौड़ते हैं .
# PRED: ये पानी की सतह पर बहुत अच्छे होते हैं और पानी वाले <UNK> सतह पर
# ----------------------------------------
# ENG: They had never been asked these strange questions .
# REF: वे भोचक़्के-से थे.ये अजीबो-गरीब सवाल उनसे पहले कभी नहीं किये गये थे .
# PRED: उनके लिए अलग <UNK> को अभियोग <UNK> से <UNK> गया
# ----------------------------------------
# BLEU score: 0.21427975344266778
